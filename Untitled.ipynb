# %%
import pandas as pd

# load data
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
df.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
def plot_state_curve(df, state: str):
    # get the indiana data
    state_df = df[df['state'] == state]
    state_df.date = state_df.date.apply(pd.to_datetime)
    # arrange by day
    day_df = state_df.drop(columns=['state', 'county']).groupby(by='date').agg(['sum'])
    day_df.head()
    day_df.plot(('cases', 'sum'))

def plot_state_counties_curve(df, state: str, counties: list):
    # get the indiana data
    state_df = df[df['state'] == state]
    counties_df = df[df.county.isin(counties)]
    state_df.date = state_df.date.apply(pd.to_datetime)
    # arrange by day
    day_df = state_df.drop(columns=['state', 'county']).groupby(by='date').agg(['sum'])
    day_df.head()
    day_df.plot(('cases', 'sum'))

# %%
plot_state_curve(df, 'Colorado')
# Out:
# /Users/olmeca/.local/share/virtualenvs/covid-YEIJ9rjg/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
plot_state_curve(df, 'Indiana')
# Out:
# /Users/olmeca/.local/share/virtualenvs/covid-YEIJ9rjg/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
plot_state_curve(df, 'Illinois')
# Out:
# /Users/olmeca/.local/share/virtualenvs/covid-YEIJ9rjg/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
plot_state_curve(df, 'New York')
# Out:
# /Users/olmeca/.local/share/virtualenvs/covid-YEIJ9rjg/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
plot_state_counties_curve(df, 'New York', ['New York City'])
# Out:
# /Users/olmeca/.local/share/virtualenvs/covid-YEIJ9rjg/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
plot_state_counties_curve(df, 'Illinois', ['Cook'])
# Out:
# /Users/olmeca/.local/share/virtualenvs/covid-YEIJ9rjg/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
